# %% [markdown]
# ### Visualizations
# Metadata Neighborhood Tabulation Areas (NTAs) were created to project populations at a small area level, from 2000 to 2030 for PlaNYC, the long-term sustainability plan for New York City. Since population size affects the error associated with population projections, these geographic units needed to have a minimum population, which we determined to be 15,000. This criterion resulted in combinations of neighborhoods that probably would not occur if one were solely designating boundaries of historical neighborhoods. Moreover, the neighborhood names associated with the neighborhood tabulation areas are not intended to be definitive. Another feature of the sustainability plan, was the creation of projections for Public Use Microdata Areas (PUMAs), which are approximations of New York City’s Community Districts developed for use with the Census Bureau’s Public Use Microdata Samples (PUMS). In order to make the boundaries consistent with PUMAs, NTAs were created using whole census tracts, from the 2010 census, within PUMAs. Since NTAs were not permitted to cross PUMA boundaries, this further restricted our ability to identify what may be thought of as historical neighborhood boundaries. Thus, users need to be cognizant of the reason why NTAs were created and the demographic/geographic constraints inherent in how they were configured. Despite these limitations, NTAs are a valuable summary level for use with both the 2010 Census and the American Community Survey (ACS). Regarding the decennial census, these geographic areas offer a good compromise between the very detailed data for census tracts (2,168) and the broad strokes provided by community districts (59). For the ACS, NTAs offer a statistically reliable alternative to the high sampling error that renders data for most individual census tracts unusable.

# %%
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import geopandas as gpd

# %%
# set up seaborn for plot consistency
def sns_reset():
    sns.set(font_scale = 1.2)
#     sns.set_style('white')
#     sns.set_style('ticks')
    sns.despine()
    # sns.set_context('poster')
    
    # colors and axes
    global color_set
    color_set = 'Blues_r' # adjust this colorset
    sns.set_palette('Blues_r')
    f, ax = plt.subplots()
    f.set_size_inches(7, 5)
    return f, ax

# %%
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
# plot airline graphs
sns.set()
f, ax = sns_reset()
f.set_size_inches(10, 6)

# set fonts
font = {'fontname':'Arial'}

sns.barplot(y = df.Borough, \
            x = df.late_response, \
           palette = 'Blues_r')
plt.title('Distribution of flight counts in 2017 for major American airlines', **font)
plt.xlabel('Number of distinct domestic flights', **font)
plt.ylabel('American airline name', **font)

plt.savefig('./visualizations/airline-flight-distribution.png', dpi = 600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f8a473cf8f0d> in <module>()
#       7 font = {'fontname':'Arial'}
#       8
# ----> 9 sns.barplot(y = df.Borough,             x = df.late_response,            palette = 'Blues_r')
#      10 plt.title('Distribution of flight counts in 2017 for major American airlines', **font)
#      11 plt.xlabel('Number of distinct domestic flights', **font)
#
# NameError: name 'df' is not defined

# %%
# https://towardsdatascience.com/lets-make-a-map-using-geopandas-pandas-and-matplotlib-to-make-a-chloropleth-map-dddc31c1983d
# https://data.cityofnewyork.us/City-Government/NTA-map/d3qk-pfyz
map_df = gpd.read_file("./geo_export_ed304d49-3aaf-4cbd-9c75-28380a34d7c6.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#      shape_area ntacode               ntaname    shape_leng countyfips  \
# 0  3.579964e+07    BK43               Midwood  27996.591274        047
# 1  3.262983e+07    BK75               Bedford  29992.919174        047
# 2  6.307284e+06    BX40         Fordham South  15878.272921        005
# 3  5.400502e+07    BK88          Borough Park  39247.227722        047
# 4  3.270695e+07    BK96  Rugby-Remsen Village  30957.853395        047
#
#    borocode  boroname                                           geometry
# 0       3.0  Brooklyn  POLYGON ((-73.94732672160586 40.62916656720947...
# 1       3.0  Brooklyn  POLYGON ((-73.94193078816201 40.70072523469552...
# 2       2.0     Bronx  POLYGON ((-73.89138023380268 40.86170058826308...
# 3       3.0  Brooklyn  POLYGON ((-73.9760493559142 40.63127590564666,...
# 4       3.0  Brooklyn  POLYGON ((-73.90855790522774 40.65209593779453...

# %%
map_df.plot()

# %%
df = pd.read_csv('./nta-metadata-3.csv')
df = df.iloc[1:]
df = df.reset_index(drop=True)
df.head()
# Out:
#                                          NTA_Name NTA_Code  TotalPop  Female  \
# 0                    Brooklyn Heights-Cobble Hill     BK09   23532.0    51.0
# 1  Sheepshead Bay-Gerritsen Beach-Manhattan Beach     BK17   63459.0    53.6
# 2                                  Brighton Beach     BK19   33146.0    53.1
# 3                            Seagate-Coney Island     BK21   29229.0    53.1
# 4                                   West Brighton     BK23   14977.0    58.8
#
#    PopU18  Pop18t24  Pop25t44  Pop45t64  Pop65pl  Hispanic      ...       \
# 0    12.8       9.4      42.2      22.5     13.1       8.9      ...
# 1    19.1       7.4      25.3      29.7     18.6       7.1      ...
# 2    17.6       7.4      24.5      28.4     22.1      12.4      ...
# 3    22.5      12.2      21.2      24.9     19.3      24.9      ...
# 4     7.6       5.3      18.8      31.9     36.3       0.5      ...
#
#    NitricOxide  NitrogenDioxide  Ozone  SulfurDioxide  Daycares  \
# 0         32.0             23.7   28.4            0.5      21.0
# 1         16.5             16.9   33.0            0.4      71.0
# 2         18.7             18.0   32.5            0.5      39.0
# 3         14.9             15.8   33.7            0.4      27.0
# 4         17.1             17.0   32.7            0.4       6.0
#
#    AlcoholRetailers  TobaccoRetailers  FelonyCrime  PropertyCrime  \
# 0              33.1               7.2         11.6            7.4
# 1              21.3               9.6         16.5            9.5
# 2              18.7               8.1         16.1            9.5
# 3              23.9              10.6         32.2           15.5
# 4               8.7               4.0         14.3           10.3
#
#    ViolentCrime
# 0           1.7
# 1           3.0
# 2           4.1
# 3           6.8
# 4           1.6
#
# [5 rows x 196 columns]

# %%
df = df[['NTA_Code','PreventHosp']]
# df = df[['nta_code', 'median_income','mean_income']]
df
# Out:
#     NTA_Code  PreventHosp
# 0       BK09        668.9
# 1       BK17       1631.2
# 2       BK19       1233.8
# 3       BK21       3158.7
# 4       BK23       1233.9
# 5       BK25       1092.3
# 6       BK26       1600.4
# 7       BK27        963.8
# 8       BK28       1020.7
# 9       BK29        997.8
# 10      BK30       1005.9
# 11      BK31       1105.7
# 12      BK32       2154.1
# 13      BK33       1973.3
# 14      BK34       1194.9
# 15      BK35       2571.0
# 16      BK37       1263.2
# 17      BK38       2589.4
# 18      BK40       1182.4
# 19      BK41       1530.7
# 20      BK42       1705.9
# 21      BK43       1446.5
# 22      BK44       1060.3
# 23      BK45       1217.9
# 24      BK46       1101.0
# 25      BK50       1760.7
# 26      BK58       1464.8
# 27      BK60       1891.3
# 28      BK61       2640.3
# 29      BK63       1973.6
# ..       ...          ...
# 165     QN61       1728.4
# 166     QN62        710.7
# 167     QN63       1269.0
# 168     QN66       1301.1
# 169     QN68       2700.0
# 170     QN70       1281.1
# 171     QN71       1955.3
# 172     QN72       1185.6
# 173     QN76       2030.9
# 174     QN98          NaN
# 175     QN99          NaN
# 176     SI01       1006.5
# 177     SI05       1251.1
# 178     SI07       1140.9
# 179     SI08       1448.0
# 180     SI11       1195.5
# 181     SI12       2083.8
# 182     SI14       1391.3
# 183     SI22       2690.6
# 184     SI24       1179.0
# 185     SI25       1184.3
# 186     SI28       1627.8
# 187     SI32       1118.1
# 188     SI35       1609.1
# 189     SI36       1620.0
# 190     SI37       2097.5
# 191     SI45       1317.8
# 192     SI48       1195.0
# 193     SI54       1041.5
# 194     SI99          NaN
#
# [195 rows x 2 columns]

# %%
merged = map_df.set_index('ntacode').join(df.set_index('nta_code'))
merged =merged.replace(np.nan, 0) 
merged = merged.loc[merged['median_income'] != 0]
merged = merged.reset_index()
merged
# Out:
#     ntacode    shape_area                                            ntaname  \
# 0      BK43  3.579964e+07                                            Midwood
# 1      BK75  3.262983e+07                                            Bedford
# 2      BX40  6.307284e+06                                      Fordham South
# 3      BK88  5.400502e+07                                       Borough Park
# 4      BK96  3.270695e+07                               Rugby-Remsen Village
# 5      QN52  2.945438e+07                                      East Flushing
# 6      QN53  3.700132e+07                                          Woodhaven
# 7      BK44  2.737916e+07                                            Madison
# 8      QN48  3.416422e+07                                         Auburndale
# 9      BX44  3.627356e+07                           Williamsbridge-Olinville
# 10     QN51  5.248828e+07                                        Murray Hill
# 11     QN27  1.972685e+07                                      East Elmhurst
# 12     BK81  3.273086e+07                                        Brownsville
# 13     BK85  1.939753e+07                   East New York (Pennsylvania Ave)
# 14     BK41  1.589335e+07                           Kensington-Ocean Parkway
# 15     BX46  9.180655e+06                                        Parkchester
# 16     BK95  1.452260e+07                                            Erasmus
# 17     QN33  3.307680e+07                                    Cambria Heights
# 18     BK91  3.436224e+07                             East Flatbush-Farragut
# 19     BK46  1.778203e+07                                Ocean Parkway South
# 20     BK93  1.159895e+07                                      Starrett City
# 21     BX35  1.689175e+07                                 Morrisania-Melrose
# 22     QN29  3.267151e+07                                           Elmhurst
# 23     QN44  4.566559e+07                Glen Oaks-Floral Park-New Hyde Park
# 24     BX33  1.073245e+07                                           Longwood
# 25     MN32  1.359478e+07                                          Yorkville
# 26     MN40  2.006533e+07                      Upper East Side-Carnegie Hill
# 27     BK40  1.404161e+07                                    Windsor Terrace
# 28     QN12  6.190412e+07                           Hammels-Arverne-Edgemere
# 29     BX27  4.973467e+07                                        Hunts Point
# ..      ...           ...                                                ...
# 158    BX22  4.904626e+07                North Riverdale-Fieldston-Riverdale
# 159    BX05  1.499888e+07                         Bedford Park-Fordham North
# 160    BX06  1.355735e+07                                            Belmont
# 161    BX07  1.519490e+07                                          Bronxdale
# 162    QN25  2.008037e+07                                             Corona
# 163    BX52  8.857046e+07           Schuylerville-Throgs Neck-Edgewater Park
# 164    BX03  4.025675e+07                    Eastchester-Edenwald-Baychester
# 165    QN10  9.944948e+07  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 166    SI32  6.495947e+07                                  Rossville-Woodrow
# 167    SI48  5.040753e+07                                      Arden Heights
# 168    QN15  5.434863e+07                             Far Rockaway-Bayswater
# 169    BK33  4.460027e+07           Carroll Gardens-Columbia Street-Red Hook
# 170    QN05  6.161493e+07                                           Rosedale
# 171    BX17  1.925641e+07                                       East Tremont
# 172    BX75  1.631622e+07                                  Crotona Park East
# 173    BX09  5.195897e+07    Soundview-Castle Hill-Clason Point-Harding Park
# 174    QN22  3.786484e+07                                           Flushing
# 175    QN62  2.655567e+07                                    Queensboro Hill
# 176    MN13  3.702973e+07         Hudson Yards-Chelsea-Flatiron-Union Square
# 177    MN21  7.531455e+06                                           Gramercy
# 178    BK09  9.984670e+06                       Brooklyn Heights-Cobble Hill
# 179    BK38  2.846257e+07   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
# 180    BK69  2.052814e+07                                       Clinton Hill
# 181    BK72  1.158999e+07                                       Williamsburg
# 182    MN04  1.609379e+07                                   Hamilton Heights
# 183    MN36  2.310022e+07                           Washington Heights South
# 184    BX26  1.645723e+07                                         Highbridge
# 185    BX63  1.936954e+07                                     West Concourse
# 186    QN17  5.782845e+07                                       Forest Hills
# 187    QN03  4.326375e+07               Springfield Gardens South-Brookville
#
#         shape_leng countyfips  borocode       boroname  \
# 0     27996.591274        047       3.0       Brooklyn
# 1     29992.919174        047       3.0       Brooklyn
# 2     15878.272921        005       2.0          Bronx
# 3     39247.227722        047       3.0       Brooklyn
# 4     30957.853395        047       3.0       Brooklyn
# 5     25843.364956        081       4.0         Queens
# 6     28070.585548        081       4.0         Queens
# 7     26237.257341        047       3.0       Brooklyn
# 8     32446.878673        081       4.0         Queens
# 9     27350.973945        005       2.0          Bronx
# 10    33266.904811        081       4.0         Queens
# 11    19816.712110        081       4.0         Queens
# 12    27300.781233        047       3.0       Brooklyn
# 13    24226.850777        047       3.0       Brooklyn
# 14    20800.556075        047       3.0       Brooklyn
# 15    12373.255538        005       2.0          Bronx
# 16    18756.702307        047       3.0       Brooklyn
# 17    26168.269540        081       4.0         Queens
# 18    39211.411680        047       3.0       Brooklyn
# 19    21975.997984        047       3.0       Brooklyn
# 20    17414.781633        047       3.0       Brooklyn
# 21    27740.845741        005       2.0          Bronx
# 22    36705.016440        081       4.0         Queens
# 23    33596.526631        081       4.0         Queens
# 24    18982.129301        005       2.0          Bronx
# 25    17409.210115        061       1.0      Manhattan
# 26    23778.406402        061       1.0      Manhattan
# 27    19033.540163        047       3.0       Brooklyn
# 28    83820.120650        081       4.0         Queens
# 29    44778.618995        005       2.0          Bronx
# ..             ...        ...       ...            ...
# 158   31856.094143        005       2.0          Bronx
# 159   22565.482200        005       2.0          Bronx
# 160   17114.430336        005       2.0          Bronx
# 161   17426.999318        005       2.0          Bronx
# 162   23870.154173        081       4.0         Queens
# 163   91012.443727        005       2.0          Bronx
# 164   59165.004771        005       2.0          Bronx
# 165  114076.635510        081       4.0         Queens
# 166   33239.330200        085       5.0  Staten Island
# 167   29689.445911        085       5.0  Staten Island
# 168   49211.108277        081       4.0         Queens
# 169   60795.911417        047       3.0       Brooklyn
# 170   63276.643517        081       4.0         Queens
# 171   29637.328295        005       2.0          Bronx
# 172   24754.759438        005       2.0          Bronx
# 173   67150.477779        005       2.0          Bronx
# 174   38363.970007        081       4.0         Queens
# 175   30555.408574        081       4.0         Queens
# 176   45454.722802        061       1.0      Manhattan
# 177   12091.587932        061       1.0      Manhattan
# 178   14253.675375        047       3.0       Brooklyn
# 179   32363.990305        047       3.0       Brooklyn
# 180   23971.461410        047       3.0       Brooklyn
# 181   16874.433579        047       3.0       Brooklyn
# 182   17410.823299        061       1.0      Manhattan
# 183   22096.305029        061       1.0      Manhattan
# 184   18507.423928        005       2.0          Bronx
# 185   28550.700370        005       2.0          Bronx
# 186   36183.607828        081       4.0         Queens
# 187   45266.267875        081       4.0         Queens
#
#                                               geometry  median_income  \
# 0    POLYGON ((-73.94732672160586 40.62916656720947...        43687.0
# 1    POLYGON ((-73.94193078816201 40.70072523469552...        37343.0
# 2    POLYGON ((-73.89138023380268 40.86170058826308...        22662.0
# 3    POLYGON ((-73.9760493559142 40.63127590564666,...        35754.0
# 4    POLYGON ((-73.90855790522774 40.65209593779453...        44027.0
# 5    POLYGON ((-73.79493246234003 40.75779803007457...        55971.0
# 6    POLYGON ((-73.84913837242911 40.69828274120191...        61804.0
# 7    POLYGON ((-73.93753749374048 40.60855739025754...        55840.0
# 8    POLYGON ((-73.77573836927105 40.74332564716403...        70772.0
# 9    POLYGON ((-73.84704957988549 40.88767181587945...        39178.0
# 10   POLYGON ((-73.80379022888253 40.77561011179251...        52696.0
# 11   POLYGON ((-73.86109724401761 40.76366447759029...        51594.0
# 12   POLYGON ((-73.89880698433517 40.65740666180451...        25041.0
# 13   POLYGON ((-73.89880698433517 40.65740666180451...        29527.0
# 14   POLYGON ((-73.97482741755584 40.64566342086813...        45483.0
# 15   POLYGON ((-73.86033845846154 40.83325316648607...        46747.0
# 16   POLYGON ((-73.9482649959084 40.63860719071172,...        40681.0
# 17   POLYGON ((-73.72677759533717 40.70305929190149...        79888.0
# 18   POLYGON ((-73.92574389425866 40.64001446624987...        50889.0
# 19   POLYGON ((-73.96285973961463 40.61254948646705...        50540.0
# 20   (POLYGON ((-73.88828531356063 40.6467224132760...        27397.0
# 21   POLYGON ((-73.89696589084865 40.83434214589528...        26339.0
# 22   POLYGON ((-73.86790963860365 40.7449337165884,...        47863.0
# 23   POLYGON ((-73.7104999536208 40.72722708741325,...        76863.0
# 24   POLYGON ((-73.8948352292406 40.82624684121225,...        24214.0
# 25   (POLYGON ((-73.93804640603445 40.7808295442755...        98840.0
# 26   POLYGON ((-73.94933170560962 40.78519312655764...       155213.0
# 27   POLYGON ((-73.97984261884459 40.66072744113143...        82297.0
# 28   POLYGON ((-73.76809925805183 40.59784597010972...        39432.0
# 29   POLYGON ((-73.88438994861662 40.8229673964486,...        22572.0
# ..                                                 ...            ...
# 158  POLYGON ((-73.89663333796997 40.91141737534828...        78895.0
# 159  POLYGON ((-73.88362518063384 40.86725758800637...        29549.0
# 160  POLYGON ((-73.8830938237215 40.86660218502373,...        21924.0
# 161  POLYGON ((-73.86137924069509 40.8713365121415,...        36859.0
# 162  (POLYGON ((-73.8544257525367 40.74885172688453...        44026.0
# 163  (POLYGON ((-73.83979488496128 40.8356192069893...        67549.0
# 164  POLYGON ((-73.79322870948383 40.88282259540829...        50334.0
# 165  (POLYGON ((-73.88346534749665 40.5684780199384...        74718.0
# 166  POLYGON ((-74.20314825968633 40.55606178461779...        83743.0
# 167  POLYGON ((-74.17185166456863 40.56152092302126...        89570.0
# 168  POLYGON ((-73.76376223381337 40.59143970953495...        41916.0
# 169  POLYGON ((-73.99236367043254 40.689690123777, ...        85496.0
# 170  POLYGON ((-73.72586264116346 40.68324108094634...        83647.0
# 171  POLYGON ((-73.88311982503737 40.84822109237927...        20879.0
# 172  POLYGON ((-73.87359713633835 40.83979855593599...        22557.0
# 173  (POLYGON ((-73.88054585187352 40.8184680223607...        36129.0
# 174  POLYGON ((-73.82331286855246 40.77957865983406...        39840.0
# 175  POLYGON ((-73.81537317355691 40.74721833785974...        53836.0
# 176  POLYGON ((-74.00153309066991 40.7626445986302,...       101369.0
# 177  POLYGON ((-73.97849845639811 40.73679095652548...       100900.0
# 178  POLYGON ((-73.99236367043254 40.689690123777, ...       105398.0
# 179  POLYGON ((-73.97905767012286 40.70595288910062...        84945.0
# 180  POLYGON ((-73.95337017508868 40.68064050844435...        66282.0
# 181  POLYGON ((-73.95023693757921 40.70547324665456...        21502.0
# 182  POLYGON ((-73.94034643247532 40.83045784284951...        39019.0
# 183  POLYGON ((-73.93139355315769 40.84742823140949...        36518.0
# 184  POLYGON ((-73.91728719351073 40.84510408615952...        23334.0
# 185  POLYGON ((-73.91191812320277 40.84325788668497...        27637.0
# 186  POLYGON ((-73.83103141767994 40.7143367252613,...        67881.0
# 187  POLYGON ((-73.75763129618157 40.66645115660705...        79042.0
#
#      mean_income
# 0        72030.0
# 1        55606.0
# 2        35499.0
# 3        55689.0
# 4        58085.0
# 5        70852.0
# 6        77846.0
# 7        73705.0
# 8        84402.0
# 9        49987.0
# 10       71925.0
# 11       66284.0
# 12       36810.0
# 13       42975.0
# 14       60412.0
# 15       54137.0
# 16       54449.0
# 17       93955.0
# 18       63993.0
# 19       76465.0
# 20       38040.0
# 21       39412.0
# 22       63971.0
# 23       93343.0
# 24       35751.0
# 25      151203.0
# 26      311109.0
# 27      102796.0
# 28       54854.0
# 29       32953.0
# ..           ...
# 158     106887.0
# 159      41324.0
# 160      31783.0
# 161      47292.0
# 162      54614.0
# 163      82109.0
# 164      61013.0
# 165      93505.0
# 166     105312.0
# 167     101627.0
# 168      59418.0
# 169     124522.0
# 170      92994.0
# 171      32330.0
# 172      33243.0
# 173      52098.0
# 174      54684.0
# 175      68064.0
# 176     182129.0
# 177     148602.0
# 178     169555.0
# 179     123292.0
# 180      86567.0
# 181      36448.0
# 182      58015.0
# 183      52338.0
# 184      35378.0
# 185      36440.0
# 186      89805.0
# 187      88502.0
#
# [188 rows x 10 columns]

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'median_income'
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# %%
from shapely.geometry import Point, Polygon
import geopandas

# https://stackoverflow.com/questions/48097742/geopandas-point-in-polygon
def coord_to_ntacode(lat, long, polys):
    pnt = Point(long, lat)
    for i in range(len(polys)):
        if pnt.within(polys['geometry'][i]):
            return polys.loc[i, 'ntacode']
    else:
        return 'null'
    
print(coord_to_ntacode(40.63, -73.93, merged))


service_requests_df = pd.read_csv('./Materials/311_service_requests.csv')
service_requests_df['ntacode'] = ''

for i in range(len(service_requests_df)):
    service_requests_df.loc[i, 'ntacode'] = coord_to_ntacode(service_requests_df.loc[i, 'latitude'], service_requests_df.loc[i, 'longitude'], merged)
service_requests_df
# Out:
# BK58
